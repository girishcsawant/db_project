# %%
from pyspark.dbutils import *
from databricks.sdk.runtime import spark
from pyspark.sql import DataFrame

# %%
dbutils.widgets.text("catalog", "data_and_analaytics_bronze_catalog")
dbutils.widgets.text("schema", "data_engineering")

# %% [markdown]
# # Default notebook
#
# This default notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %%
# Set default catalog and schema
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"USE SCHEMA {schema}")
# Out:
# DataFrame[]

# %%
df = spark.sql("select * from data_and_analaytics_bronze_catalog.data_engineering.forecast_daily_calendar_imperial")
display(df)
